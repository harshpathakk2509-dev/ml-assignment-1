# %% [markdown]
# **1. What is a parameter?**
#
# **ANSWER**
#
# A parameter is a variable that defines a model’s configuration or behavior. In Machine Learning, parameters are learned from data during training (e.g., weights in linear regression).
#
# **2. What is correlation? What does negative correlation mean?**
#
# **ANSWER**
#
# Correlation measures the strength and direction of a linear relationship between two variables.
#
# Positive correlation: both variables increase together.
#
# Negative correlation: one variable increases while the other decreases.
#
# **3. Define Machine Learning. What are the main components in Machine Learning?**
#
# **ANSWER**
#
# Machine Learning is a field of AI where systems learn patterns from data to make predictions or decisions without explicit programming.
# Main components:
#
# Data
#
# Features
#
# Model
#
# Training (learning process)
#
# Evaluation (testing performance)
#
# **4. How does loss value help in determining whether the model is good or not?**
#
# **ANSWER**
#
# Loss value measures the difference between predicted and actual results. A lower loss indicates better model performance.
#
# **5. What are continuous and categorical variables?**
#
# **ANSWER**
#
# Continuous: numerical values with infinite possibilities (e.g., height, weight).
#
# Categorical: discrete values representing categories (e.g., gender, color).
#
# **6. How do we handle categorical variables in Machine Learning? What are the common techniques?**
#
# **ANSWER**
#
# Common techniques:
#
# Label Encoding
#
# One-Hot Encoding
#
# Ordinal Encoding
#
# **7. What do you mean by training and testing a dataset?**
#
# **ANSWER**
#
#
# Training dataset: used to teach the model.
#
# Testing dataset: used to evaluate how well the model generalizes to unseen data.
#
# **8. What is sklearn.preprocessing?**
#
# **ANSWER**
#
# It is a module in scikit-learn that provides functions for preprocessing data, such as scaling, encoding, and normalization.
#
# **9. What is a Test set?**
#
#
# **ANSWER**
#
# A test set is a portion of data reserved to evaluate the performance of a trained model.
#
# **10. How do we split data for model fitting (training and testing) in Python? How do you approach a Machine Learning problem?**
#
# **ANSWER**
#
# Use train_test_split from scikit-learn.
#
# Approach: Define problem → Collect data → Perform EDA → Preprocess → Train model → Evaluate → Deploy.
#
# **11. Why do we have to perform EDA before fitting a model to the data?**
#
# **ANSWER**
#
# Exploratory Data Analysis (EDA) helps understand data distribution, detect missing values, outliers, and relationships, ensuring better preprocessing and model accuracy.
#
# **12. What is correlation?**
#
# **ANSWER**
#
# Correlation is the statistical measure of how two variables move in relation to each other.
#
# **13. What does negative correlation mean?**
#
# **ANSWER**
#
# It means when one variable increases, the other decreases.
#
# **14. How can you find correlation between variables in Python?**
# Using df.corr() in pandas or numpy.corrcoef().
#
# **15. What is causation? Explain difference between correlation and causation with an example.**
#
# **ANSWER**
#
# Causation means one variable directly affects another.
# Example: Ice cream sales and sunburns are correlated, but sunburns are caused by sunlight, not ice cream.
#
# **16. What is an Optimizer? What are different types of optimizers? Explain each with an example.**|
#
# **ANSWER**
#
# An optimizer updates model parameters to minimize loss.
# Types:
#
# Gradient Descent
#
# Stochastic Gradient Descent (SGD)
#
# Adam Optimizer
# Example: Adam combines momentum and adaptive learning rates for faster convergence.
#
# **17. What is sklearn.linear_model?**
#
# **ANSWER**
#
# It is a module in scikit-learn that provides linear models like Linear Regression, Logistic Regression, Ridge, and Lasso.
#
# **18. What does model.fit() do? What arguments must be given?**
#
# **ANSWER**
#
# model.fit(X, y) trains the model using input features X and target labels y.
#
# **19. What does model.predict() do? What arguments must be given?**
#
# **ANSWER**
#
# model.predict(X) generates predictions for new input data X.
#
# **20. What are continuous and categorical variables?**
#
#
# **ANSWER**
#
# Continuous: numerical values (e.g., salary).
#
# Categorical: labels or categories (e.g., city names).
#
# **21. What is feature scaling? How does it help in Machine Learning?**
#
# **ANSWER**
#
# Feature scaling standardizes or normalizes data so that all features contribute equally. It improves model accuracy and convergence speed.
#
# **22. How do we perform scaling in Python?**
#
# **ANSWER**
#
# Using StandardScaler or MinMaxScaler from sklearn.preprocessing.
#
# **23. What is sklearn.preprocessing?**
#
# **ANSWER**
#
# It is a preprocessing module for scaling, encoding, and transforming data before training.
#
# **24. How do we split data for model fitting (training and testing) in Python?**
#
# **ANSWER**
#
# Using train_test_split(X, y, test_size=0.2) from scikit-learn.
#
# **25. Explain data encoding.**
#
# **ANSWER**
#
# Data encoding converts categorical variables into numerical form.
# Examples:
#
# Label Encoding assigns integers to categories.
#
# One-Hot Encoding creates binary columns for each category.
